# %% [markdown]
# # Recomendaciones proyecto
#
#
# 1. **Rendimiento esperado:**
#    - No es necesario alcanzar un rendimiento cercano al **100%** para obtener la nota máxima en el proyecto. Se evaluará la calidad del enfoque, la justificación de las decisiones tomadas y la interpretación de los resultados obtenidos.
#
# 2. **Uso de muestras en caso de limitaciones:**
#    - Si su equipo no puede cargar o procesar todos los datos debido a limitaciones de recursos (como RAM), puede trabajar con **muestras representativas del conjunto de datos**.
#    - Es **obligatorio justificar** este enfoque en el informe, explicando claramente las razones detrás de la decisión y cómo se asegura que las muestras son representativas.
#
# 3. **Optimización de recursos:**
#    - Si enfrenta problemas de memoria al ejecutar tareas, **reduzca la cantidad de procesos paralelos** (**jobs**) a un nivel que su computador o intérprete web pueda manejar. Es preferible priorizar la estabilidad del proceso sobre la velocidad.
#
# 4. **Paralelización para búsquedas de hiperparámetros:**
#    - Aproveche la paralelización para acelerar la búsqueda de hiperparámetros, especialmente si esta es un cuello de botella en su proyecto. Herramientas como `GridSearchCV`, `RandomizedSearchCV` o `Optuna` suelen permitir paralelización configurando el parámetro `n_jobs`.
#
# 5. **Grillas de búsqueda razonables:**
#    - Al realizar búsquedas de hiperparámetros, **diseñe grillas de búsqueda razonables** que no sean excesivamente grandes.
#    - Recuerde que, aunque explorar un mayor espacio de hiperparámetros puede parecer atractivo, también puede hacer que el proceso sea extremadamente lento o inviable. Ajuste el tamaño de las grillas para garantizar que la búsqueda **converja en tiempos razonables** y no tome **"3.5 eternidades"**.

# %% [markdown]
# A continuación, se detallan las tareas que deben completar para la **Entrega Parcial 1**. Recuerden que el principal entregable es **predecir, con su mejor modelo, sobre los clientes del archivo `X_t1.parquet` y subir las predicciones a la plataforma CodaLab**. **Para esta entrega el desarrollo del informe es sugerido, pero no mandatorio**. Asegúrense de utilizar el archivo correspondiente para subir los resultados a la competencia. El uso de datos incorrectos se reflejará en un bajo desempeño en la tabla de clasificación.
#
# ### **Tareas a realizar:**
# 1. **Análisis exploratorio de datos:**
#    Realicen un análisis detallado para identificar patrones, tendencias y relaciones en los datos. Este paso les permitirá comprender mejor las características del conjunto de datos y guiar las siguientes decisiones en el pipeline de modelamiento.
#
# 2. **Preprocesamiento de datos:**
#    Incluyan técnicas de preprocesamiento que aseguren la calidad y adecuación de los datos para los modelos. Algunas tareas sugeridas son:
#    - Estandarización de filas y/o columnas.
#    - Reducción de dimensionalidad.
#    - Discretización de variables numéricas a categóricas.
#    - Manejo de datos nulos.
#    - Otras transformaciones relevantes según los datos disponibles.
#
# 3. **División del conjunto de datos:**
#    Implementen una técnica **Hold-Out**, separando el conjunto de datos en **70% para entrenamiento** y **30% para testeo**.
#
# 4. **Creación de un modelo baseline:**
#    Entrenen un modelo sencillo que sirva como línea base para comparar el rendimiento de los modelos más avanzados.
#
# 5. **Desarrollo de 3 modelos de Machine Learning diferentes al baseline:**
#    - Utilicen exclusivamente pipelines de **Scikit-Learn** para esta iteración del proyecto.
#    - El uso de librerías o herramientas externas será penalizado con una calificación de **0** en las secciones implicadas.
#
# 6. **Interpretabilidad del modelo con mejores resultados:**
#    Apliquen técnicas que permitan interpretar y justificar los resultados obtenidos por el modelo con mejor desempeño.

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# # Informe Proyecto Lab
# Integrantes:
# - Alonso Uribe
# - Carolina Núñez
#
# Grupo: Adaval

# %% [markdown]
# #### **1. Introducción [0.25 puntos]**
# Esta sección debe incluir:
# - Una breve descripción del problema planteado: ¿Qué se intenta predecir?
# - Un resumen de los datos de entrada proporcionados.
# - La métrica seleccionada para evaluar los modelos, justificando su elección. Considerando que los datos están desbalanceados, eviten usar `accuracy` y enfoquen su análisis en métricas como `precision`, `recall` o `f1-score`, indicando en qué clase se centrarán.
# - Una mención breve de los modelos utilizados para resolver el problema, incluyendo las transformaciones intermedias aplicadas a los datos.
# - Un cierre con un análisis general de los resultados obtenidos, indicando si el modelo final cumplió con los objetivos y cómo se posicionaron respecto a otros equipos.

# %%
import datetime
import numpy as np 
import pandas as pd 
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from collections import defaultdict
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, FunctionTransformer
from sklearn.impute import SimpleImputer


maxcols = pd.get_option("display.max_columns")
pd.set_option("display.max_columns", None)

# %%
# para entrenar
X_t0 = pd.read_parquet('X_t0.parquet')
y_t0 = pd.read_parquet('y_t0.parquet')
# para predecir(?)
X_t1 = pd.read_parquet('X_t1.parquet')
X_t0 = X_t0[sorted(X_t0.columns)]
X_t1 = X_t1[sorted(X_t1.columns)]

# %% [markdown]
# # Analisis exploratorio de los datos

# %% [markdown]
# #### **2. Modelos con Scikit-Learn (Entrega Parcial 1)**
#
# ##### **2.1. Análisis Exploratorio de Datos [0.5 puntos]**
# Realicen un análisis que explore patrones, tendencias y relaciones clave en los datos. Incluyan:
# - Estadísticas descriptivas generales.
# - Visualizaciones para identificar distribuciones, valores atípicos y posibles relaciones entre variables.
# - Cualquier observación relevante que pueda influir en las etapas posteriores del proyecto.
#
# El informe debe ser detallado y profesional, demostrando no solo la implementación técnica, sino también una comprensión profunda de los datos y la problemática planteada.

# %%
pd.set_option("display.max_columns", maxcols )
X_t0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44296 entries, 0 to 44295
# Data columns (total 77 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   avg_gas_paid_per_tx_eth                  44296 non-null  float64
#  1   avg_risk_factor                          44296 non-null  float64
#  2   avg_weighted_risk_factor                 44296 non-null  float64
#  3   borrow_amount_avg_eth                    44296 non-null  float64
#  4   borrow_amount_sum_eth                    44296 non-null  float64
#  5   borrow_block_number                      44296 non-null  int64
#  6   borrow_count                             44296 non-null  int64
#  7   borrow_repay_diff_eth                    44296 non-null  float64
#  8   borrow_timestamp                         44296 non-null  float64
#  9   deposit_amount_sum_eth                   44296 non-null  float64
#  10  deposit_count                            44296 non-null  int64
#  11  first_tx_timestamp                       44296 non-null  float64
#  12  incoming_tx_avg_eth                      44296 non-null  float64
#  13  incoming_tx_count                        44296 non-null  int64
#  14  incoming_tx_sum_eth                      44296 non-null  float64
#  15  last_tx_timestamp                        44296 non-null  float64
#  16  liquidation_amount_sum_eth               44296 non-null  float64
#  17  liquidation_count                        44296 non-null  int64
#  18  market_adx                               44296 non-null  float64
#  19  market_adxr                              44296 non-null  float64
#  20  market_apo                               44296 non-null  float64
#  21  market_aroonosc                          44296 non-null  float64
#  22  market_aroonup                           44296 non-null  float64
#  23  market_atr                               44296 non-null  float64
#  24  market_cci                               44296 non-null  float64
#  25  market_cmo                               44296 non-null  float64
#  26  market_correl                            44296 non-null  float64
#  27  market_dx                                44296 non-null  float64
#  28  market_fastd                             44296 non-null  float64
#  29  market_fastk                             44296 non-null  float64
#  30  market_ht_trendmode                      44296 non-null  int64
#  31  market_linearreg_slope                   44296 non-null  float64
#  32  market_macd                              44296 non-null  float64
#  33  market_macd_macdext                      44296 non-null  float64
#  34  market_macd_macdfix                      44296 non-null  float64
#  35  market_macdsignal                        44296 non-null  float64
#  36  market_macdsignal_macdext                44296 non-null  float64
#  37  market_macdsignal_macdfix                44296 non-null  float64
#  38  market_max_drawdown_365d                 44296 non-null  float64
#  39  market_natr                              44296 non-null  float64
#  40  market_plus_di                           44296 non-null  float64
#  41  market_plus_dm                           44296 non-null  float64
#  42  market_ppo                               44296 non-null  float64
#  43  market_rocp                              44296 non-null  float64
#  44  market_rocr                              44296 non-null  float64
#  45  max_eth_ever                             44296 non-null  float64
#  46  max_risk_factor                          44296 non-null  float64
#  47  min_eth_ever                             44296 non-null  float64
#  48  net_incoming_tx_count                    44296 non-null  int64
#  49  outgoing_tx_avg_eth                      44296 non-null  float64
#  50  outgoing_tx_count                        44296 non-null  int64
#  51  outgoing_tx_sum_eth                      44296 non-null  float64
#  52  repay_amount_avg_eth                     44296 non-null  float64
#  53  repay_amount_sum_eth                     44296 non-null  float64
#  54  repay_count                              44296 non-null  int64
#  55  risk_factor                              44296 non-null  float64
#  56  risk_factor_above_threshold_daily_count  44296 non-null  float64
#  57  risky_first_last_tx_timestamp_diff       44296 non-null  int64
#  58  risky_first_tx_timestamp                 44296 non-null  int64
#  59  risky_last_tx_timestamp                  44296 non-null  int64
#  60  risky_sum_outgoing_amount_eth            44296 non-null  float64
#  61  risky_tx_count                           44296 non-null  int64
#  62  risky_unique_contract_count              44296 non-null  int64
#  63  time_since_first_deposit                 44296 non-null  float64
#  64  time_since_last_liquidated               44296 non-null  float64
#  65  total_available_borrows_avg_eth          44296 non-null  float64
#  66  total_available_borrows_eth              44296 non-null  float64
#  67  total_balance_eth                        44296 non-null  float64
#  68  total_collateral_avg_eth                 44296 non-null  float64
#  69  total_collateral_eth                     44296 non-null  float64
#  70  total_gas_paid_eth                       44296 non-null  float64
#  71  unique_borrow_protocol_count             44296 non-null  int64
#  72  unique_lending_protocol_count            44296 non-null  int64
#  73  wallet_address                           44296 non-null  object
#  74  wallet_age                               44296 non-null  float64
#  75  withdraw_amount_sum_eth                  44296 non-null  float64
#  76  withdraw_deposit_diff_if_positive_eth    44296 non-null  float64
# dtypes: float64(60), int64(16), object(1)
# memory usage: 26.0+ MB

# %%
y_t0.value_counts()
# Out:
# target
# 1         22656
# 0         21640
# Name: count, dtype: int64

# %%
# Verificamos que no hayan valores nulos
X_t0.isnull().sum()
# Out:
# avg_gas_paid_per_tx_eth                  0
# avg_risk_factor                          0
# avg_weighted_risk_factor                 0
# borrow_amount_avg_eth                    0
# borrow_amount_sum_eth                    0
#                                         ..
# unique_lending_protocol_count            0
# wallet_address                           0
# wallet_age                               0
# withdraw_amount_sum_eth                  0
# withdraw_deposit_diff_if_positive_eth    0
# Length: 77, dtype: int64

# %%
numeric_var = X_t0.select_dtypes(include=['number']).columns
object_var = X_t0.select_dtypes(include=['object']).columns
timestamps = pd.Index([col for col in X_t0.columns if "timestamp" in col])
numeric_var = numeric_var.drop(timestamps)
timestamps = timestamps.drop('risky_first_last_tx_timestamp_diff')
ts_diff_col = pd.Index(['risky_first_last_tx_timestamp_diff'])

# %%
# X_t0['tx_diff'] = X_t0['last_tx_timestamp']- X_t0['first_tx_timestamp']
# timestamps += ['tx_diff']

# %% [markdown]
# Observamos que las columnas timestamp hablan de fechas de transacción. Sin conocimiento del negocio, hablan de una fecha inicio y termino del prestamo(?)

# %%
(X_t0[ts_diff_col[0]] == (X_t0['risky_last_tx_timestamp']) - X_t0['risky_first_tx_timestamp']).sum()/ len(X_t0)
# Out:
# np.float64(1.0)

# %% [markdown]
# Aquí podemos ver que la columna `risky_first_last_tx_timestamp_diff` corresponde a la diferencia entre las columnas `risky_last_tx_timestamp` y `risky_first_tx_timestamp`.
# Por lo tanto debemos decidir que necesitamos del fenómeno, los valores absolutos en el tiempo, o solo la diferencia de estos valores. Concluimos que estos tres valores junto no entraran al modelo.

# %% [markdown]
# Con la variable `borrow_timestamp` podemos hacer una cuenta simple de las veces que cada cliente pidio un prestamo y agregar esta variable al dataset, descartando este campo.

# %%
X_t0.head()
# Out:
#    avg_gas_paid_per_tx_eth  avg_risk_factor  avg_weighted_risk_factor  \
# 0                 0.000981         0.000000                  0.000000
# 1                 0.000983         0.000001                  0.000000
# 2                 0.000985         0.002477                  0.000387
# 3                 0.010786         0.000000                  0.000000
# 4                 0.001003         0.000000                  0.000000
#
#    borrow_amount_avg_eth  borrow_amount_sum_eth  borrow_block_number  \
# 0               0.000000               0.000000              7711117
# 1               0.157110               0.157110              7711123
# 2               0.271637               0.543275              7711126
# 3               0.000000               0.000000              7711672
# 4               0.000000               0.000000              7712572
#
#    borrow_count  borrow_repay_diff_eth  borrow_timestamp  \
# 0             0               0.000000      1.557197e+09
# 1             1               0.157110      1.557197e+09
# 2             2               0.543275      1.557197e+09
# 3             0               0.000000      1.557205e+09
# 4             0               0.000000      1.557217e+09
#
#    deposit_amount_sum_eth  ...  total_balance_eth  total_collateral_avg_eth  \
# 0               44.410991  ...          58.317987                  0.000000
# 1               44.410991  ...          58.317987                 44.479139
# 2               44.410991  ...          58.317987                 44.479139
# 3                0.000772  ...           0.000000                  0.000000
# 4                0.010000  ...           0.000000                  0.000000
#
#    total_collateral_eth  total_gas_paid_eth  unique_borrow_protocol_count  \
# 0             44.479139            0.397391                             0
# 1             44.479139            0.399063                             1
# 2             44.479139            0.400895                             1
# 3              0.000767            0.604001                             0
# 4              0.010000            0.003008                             0
#
#    unique_lending_protocol_count                              wallet_address  \
# 0                              1  0x502cb8985b2c92a8d4bf309cdaa89de9be442708
# 1                              1  0x502cb8985b2c92a8d4bf309cdaa89de9be442708
# 2                              1  0x502cb8985b2c92a8d4bf309cdaa89de9be442708
# 3                              1  0xa7ff0d561cd15ed525e31bbe0af3fe34ac2059f6
# 4                              1  0xbd9ed130a53cfafcf81502e4d35329a6c4d53410
#
#    wallet_age  withdraw_amount_sum_eth  withdraw_deposit_diff_if_positive_eth
# 0  19973049.0                      0.0                                    0.0
# 1  19973188.0                      0.0                                    0.0
# 2  19973238.0                      0.0                                    0.0
# 3     13922.0                      0.0                                    0.0
# 4       264.0                      0.0                                    0.0
#
# [5 rows x 77 columns]

# %%
# borrow_times : numero de prestamos por cliente 
vars = object_var.insert(len(object_var), 'borrow_timestamp')
borrow_per_cli = X_t0[vars].groupby(*object_var).count().rename(columns={'borrow_timestamp':'borrow_times'})
borrow_per_cli = borrow_per_cli.reset_index()

# %%
# X_t0 = X_t0.merge(borrow_per_cli, on='wallet_address')
# X_t0 = X_t0[sorted(X_t0.columns)]
# X_t0.head()

# %%
# Busca las variables binarias a partir del número de valores distintos que tenga
from feature_engine.selection import DropConstantFeatures
weird = defaultdict(list)
threshold = 0.5

for col in X_t0[numeric_var]:
    diff_values = len(X_t0[col].value_counts())
    min_prop = (X_t0[col] == X_t0[col].min()).sum() / len(X_t0[col]) 
    max_prop = (X_t0[col] == X_t0[col].max()).sum() / len(X_t0[col])
    
    is_binary = diff_values == 2
    is_weird = False
    if min_prop > threshold and not is_binary :
        weird['min_prop'].append(col)
        is_weird = True
    if max_prop > threshold and not is_binary :
        weird['max_prop'].append(col)
        is_weird = True
    if is_binary:
        weird['binary'].append(col)
        is_weird = True
    if not is_weird:
        weird['not'].append(col)
    print(f"{col}:\n # valores distintos: {diff_values}\n Proporción de valor mínimo: {min_prop}\n Proporción de valor máximo: {max_prop};\n\n")
# Out:
# avg_gas_paid_per_tx_eth:
#  # valores distintos: 44247
#  Proporción de valor mínimo: 0.000428932635000903
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# avg_risk_factor:
#  # valores distintos: 33887
#  Proporción de valor mínimo: 0.1553639154776955
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# avg_weighted_risk_factor:
#  # valores distintos: 33815
#  Proporción de valor mínimo: 0.2322557341520679
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# borrow_amount_avg_eth:
#  # valores distintos: 35723
#  Proporción de valor mínimo: 0.16005959906086328
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# borrow_amount_sum_eth:
#  # valores distintos: 34824
#  Proporción de valor mínimo: 0.16005959906086328
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# borrow_block_number:
#  # valores distintos: 42584
#  Proporción de valor mínimo: 2.257540184215279e-05
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# borrow_count:
#  # valores distintos: 2466
#  Proporción de valor mínimo: 0.15324182770453315
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# borrow_repay_diff_eth:
#  # valores distintos: 30321
#  Proporción de valor mínimo: 0.28101860213111796
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# deposit_amount_sum_eth:
#  # valores distintos: 29979
#  Proporción de valor mínimo: 0.034111432183492864
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# deposit_count:
#  # valores distintos: 2068
#  Proporción de valor mínimo: 0.029731804226115224
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# incoming_tx_avg_eth:
#  # valores distintos: 44065
#  Proporción de valor mínimo: 2.257540184215279e-05
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# incoming_tx_count:
#  # valores distintos: 5193
#  Proporción de valor mínimo: 0.006050207693696948
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# incoming_tx_sum_eth:
#  # valores distintos: 41229
#  Proporción de valor mínimo: 2.257540184215279e-05
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# liquidation_amount_sum_eth:
#  # valores distintos: 1190
#  Proporción de valor mínimo: 0.7765035217626873
#  Proporción de valor máximo: 0.0005192342423695141;
#
#
# liquidation_count:
#  # valores distintos: 138
#  Proporción de valor mínimo: 0.7749458190355788
#  Proporción de valor máximo: 0.0005192342423695141;
#
#
# market_adx:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0027316236229004876
#  Proporción de valor máximo: 0.004673108181325628;
#
#
# market_adxr:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0027316236229004876
#  Proporción de valor máximo: 0.002934802239479863;
#
#
# market_apo:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0023026909878995847
#  Proporción de valor máximo: 0.000857865270001806;
#
#
# market_aroonosc:
#  # valores distintos: 62
#  Proporción de valor mínimo: 0.003544338089217988
#  Proporción de valor máximo: 0.001399674914213473;
#
#
# market_aroonup:
#  # valores distintos: 15
#  Proporción de valor mínimo: 0.17048943471193787
#  Proporción de valor máximo: 0.13005689001264223;
#
#
# market_atr:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0032960086689543073
#  Proporción de valor máximo: 0.002799349828426946;
#
#
# market_cci:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0036120642947444466
#  Proporción de valor máximo: 0.004244175546324724;
#
#
# market_cmo:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0036120642947444466
#  Proporción de valor máximo: 0.0039958461260610435;
#
#
# market_correl:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0018060321473722233
#  Proporción de valor máximo: 0.003205707061585696;
#
#
# market_dx:
#  # valores distintos: 336
#  Proporción de valor mínimo: 0.0013545241105291674
#  Proporción de valor máximo: 9.030160736861116e-05;
#
#
# market_fastd:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0015577027271085424
#  Proporción de valor máximo: 0.003454036481849377;
#
#
# market_fastk:
#  # valores distintos: 410
#  Proporción de valor mínimo: 0.0033863102763229186
#  Proporción de valor máximo: 0.006411414123171392;
#
#
# market_ht_trendmode:
#  # valores distintos: 2
#  Proporción de valor mínimo: 0.16064655950875925
#  Proporción de valor máximo: 0.8393534404912407;
#
#
# market_linearreg_slope:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.004763409788694239
#  Proporción de valor máximo: 6.772620552645837e-05;
#
#
# market_macd:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.004763409788694239
#  Proporción de valor máximo: 0.0030702546505327797;
#
#
# market_macd_macdext:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0023026909878995847
#  Proporción de valor máximo: 0.000857865270001806;
#
#
# market_macd_macdfix:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.004763409788694239
#  Proporción de valor máximo: 0.0030702546505327797;
#
#
# market_macdsignal:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0023026909878995847
#  Proporción de valor máximo: 0.002483294202636807;
#
#
# market_macdsignal_macdext:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0018060321473722233
#  Proporción de valor máximo: 0.0018286075492143761;
#
#
# market_macdsignal_macdfix:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0023026909878995847
#  Proporción de valor máximo: 0.002483294202636807;
#
#
# market_max_drawdown_365d:
#  # valores distintos: 70
#  Proporción de valor mínimo: 0.00018060321473722233
#  Proporción de valor máximo: 0.01537384865450605;
#
#
# market_natr:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0039958461260610435
#  Proporción de valor máximo: 0.0024155679971103487;
#
#
# market_plus_di:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0012416471013184036
#  Proporción de valor máximo: 9.030160736861116e-05;
#
#
# market_plus_dm:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0012416471013184036
#  Proporción de valor máximo: 9.030160736861116e-05;
#
#
# market_ppo:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0023026909878995847
#  Proporción de valor máximo: 0.0010384684847390283;
#
#
# market_rocp:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0024155679971103487
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# market_rocr:
#  # valores distintos: 412
#  Proporción de valor mínimo: 0.0024155679971103487
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# max_eth_ever:
#  # valores distintos: 9095
#  Proporción de valor mínimo: 0.04596351815062308
#  Proporción de valor máximo: 4.515080368430558e-05;
#
#
# max_risk_factor:
#  # valores distintos: 8637
#  Proporción de valor mínimo: 0.1553639154776955
#  Proporción de valor máximo: 0.0006772620552645837;
#
#
# min_eth_ever:
#  # valores distintos: 7822
#  Proporción de valor mínimo: 0.04596351815062308
#  Proporción de valor máximo: 6.772620552645837e-05;
#
#
# net_incoming_tx_count:
#  # valores distintos: 3146
#  Proporción de valor mínimo: 2.257540184215279e-05
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# outgoing_tx_avg_eth:
#  # valores distintos: 43140
#  Proporción de valor mínimo: 0.021559508759255913
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# outgoing_tx_count:
#  # valores distintos: 6220
#  Proporción de valor mínimo: 0.000428932635000903
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# outgoing_tx_sum_eth:
#  # valores distintos: 39320
#  Proporción de valor mínimo: 0.021559508759255913
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# repay_amount_avg_eth:
#  # valores distintos: 13498
#  Proporción de valor mínimo: 0.33556077298175907
#  Proporción de valor máximo: 6.772620552645837e-05;
#
#
# repay_amount_sum_eth:
#  # valores distintos: 13419
#  Proporción de valor mínimo: 0.33556077298175907
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# repay_count:
#  # valores distintos: 839
#  Proporción de valor mínimo: 0.3298943471193787
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# risk_factor:
#  # valores distintos: 31402
#  Proporción de valor mínimo: 2.257540184215279e-05
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# risk_factor_above_threshold_daily_count:
#  # valores distintos: 6588
#  Proporción de valor mínimo: 0.5628047679248691
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# risky_sum_outgoing_amount_eth:
#  # valores distintos: 4387
#  Proporción de valor mínimo: 0.8378408885678165
#  Proporción de valor máximo: 0.000428932635000903;
#
#
# risky_tx_count:
#  # valores distintos: 108
#  Proporción de valor mínimo: 0.8194193606646198
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# risky_unique_contract_count:
#  # valores distintos: 24
#  Proporción de valor mínimo: 0.8194193606646198
#  Proporción de valor máximo: 4.515080368430558e-05;
#
#
# time_since_first_deposit:
#  # valores distintos: 40853
#  Proporción de valor mínimo: 0.029731804226115224
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# time_since_last_liquidated:
#  # valores distintos: 9811
#  Proporción de valor mínimo: 2.257540184215279e-05
#  Proporción de valor máximo: 0.7749458190355788;
#
#
# total_available_borrows_avg_eth:
#  # valores distintos: 37125
#  Proporción de valor mínimo: 0.1553639154776955
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# total_available_borrows_eth:
#  # valores distintos: 41662
#  Proporción de valor mínimo: 2.257540184215279e-05
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# total_balance_eth:
#  # valores distintos: 24180
#  Proporción de valor mínimo: 0.04596351815062308
#  Proporción de valor máximo: 4.515080368430558e-05;
#
#
# total_collateral_avg_eth:
#  # valores distintos: 36828
#  Proporción de valor mínimo: 0.1553639154776955
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# total_collateral_eth:
#  # valores distintos: 38220
#  Proporción de valor mínimo: 0.022056167599783277
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# total_gas_paid_eth:
#  # valores distintos: 44250
#  Proporción de valor mínimo: 0.000428932635000903
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# unique_borrow_protocol_count:
#  # valores distintos: 2
#  Proporción de valor mínimo: 0.15324182770453315
#  Proporción de valor máximo: 0.8467581722954669;
#
#
# unique_lending_protocol_count:
#  # valores distintos: 2
#  Proporción de valor mínimo: 0.029731804226115224
#  Proporción de valor máximo: 0.9702681957738848;
#
#
# wallet_age:
#  # valores distintos: 44069
#  Proporción de valor mínimo: 2.257540184215279e-05
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# withdraw_amount_sum_eth:
#  # valores distintos: 12829
#  Proporción de valor mínimo: 0.25887213292396605
#  Proporción de valor máximo: 2.257540184215279e-05;
#
#
# withdraw_deposit_diff_if_positive_eth:
#  # valores distintos: 1488
#  Proporción de valor mínimo: 0.9482120281741016
#  Proporción de valor máximo: 2.257540184215279e-05;

# %%
transformer = DropConstantFeatures(tol=threshold)
transformer.fit_transform(X_t0[numeric_var])
cuasiconstant = transformer.features_to_drop_
# cuasiconstant

# %%
for name, keys in weird.items():
    print(f"{name.upper()}:\n {', '.join(sorted(keys))}\n")
# Out:
# NOT:
#  avg_gas_paid_per_tx_eth, avg_risk_factor, avg_weighted_risk_factor, borrow_amount_avg_eth, borrow_amount_sum_eth, borrow_block_number, borrow_count, borrow_repay_diff_eth, deposit_amount_sum_eth, deposit_count, incoming_tx_avg_eth, incoming_tx_count, incoming_tx_sum_eth, market_adx, market_adxr, market_apo, market_aroonosc, market_aroonup, market_atr, market_cci, market_cmo, market_correl, market_dx, market_fastd, market_fastk, market_linearreg_slope, market_macd, market_macd_macdext, market_macd_macdfix, market_macdsignal, market_macdsignal_macdext, market_macdsignal_macdfix, market_max_drawdown_365d, market_natr, market_plus_di, market_plus_dm, market_ppo, market_rocp, market_rocr, max_eth_ever, max_risk_factor, min_eth_ever, net_incoming_tx_count, outgoing_tx_avg_eth, outgoing_tx_count, outgoing_tx_sum_eth, repay_amount_avg_eth, repay_amount_sum_eth, repay_count, risk_factor, time_since_first_deposit, total_available_borrows_avg_eth, total_available_borrows_eth, total_balance_eth, total_collateral_avg_eth, total_collateral_eth, total_gas_paid_eth, wallet_age, withdraw_amount_sum_eth
#
# MIN_PROP:
#  liquidation_amount_sum_eth, liquidation_count, risk_factor_above_threshold_daily_count, risky_sum_outgoing_amount_eth, risky_tx_count, risky_unique_contract_count, withdraw_deposit_diff_if_positive_eth
#
# BINARY:
#  market_ht_trendmode, unique_borrow_protocol_count, unique_lending_protocol_count
#
# MAX_PROP:
#  time_since_last_liquidated

# %%
pd.set_option("display.max_columns", None)
X_t0[weird['max_prop']].describe()
# Out:
#        time_since_last_liquidated
# count                4.429600e+04
# mean                 7.754784e+08
# std                  4.166387e+08
# min                  8.000000e+00
# 25%                  1.000000e+09
# 50%                  1.000000e+09
# 75%                  1.000000e+09
# max                  1.000000e+09

# %%
X_t0[weird['min_prop']].describe()
# Out:
#        liquidation_amount_sum_eth  liquidation_count  \
# count                44296.000000       44296.000000
# mean                  2374.206031           7.432364
# std                  11585.656295          28.850631
# min                      0.000000           0.000000
# 25%                      0.000000           0.000000
# 50%                      0.000000           0.000000
# 75%                      0.000000           0.000000
# max                  84050.817324         184.000000
#
#        risk_factor_above_threshold_daily_count  risky_sum_outgoing_amount_eth  \
# count                             4.429600e+04                   44296.000000
# mean                              5.741237e+04                     888.809718
# std                               3.201195e+05                   10556.796626
# min                               0.000000e+00                       0.000000
# 25%                               0.000000e+00                       0.000000
# 50%                               0.000000e+00                       0.000000
# 75%                               9.900000e+01                       0.000000
# max                               3.125567e+06                  237072.330260
#
#        risky_tx_count  risky_unique_contract_count  \
# count    44296.000000                 44296.000000
# mean         1.639426                     0.455075
# std          6.430854                     1.407241
# min          0.000000                     0.000000
# 25%          0.000000                     0.000000
# 50%          0.000000                     0.000000
# 75%          0.000000                     0.000000
# max        122.000000                    58.000000
#
#        withdraw_deposit_diff_if_positive_eth
# count                           44296.000000
# mean                              231.373416
# std                              4758.504180
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                            710786.012201

# %% [markdown]
# ### Test de Anderson
#
# Para determinar que variables se comportan de manera gaussiana, se implementará el test de D'Agostino and Pearson con nivel de significancia del 95%, cuya hipótesis nula es que los datos provienen de una distribución dada. En este caso, de una distribución normal. Entonces, si el p-value es menor al nivel de significancia se rechaza la nula, es decir, los datos no provienen de una distribución normal.
#
# (Este test es similar al Test de Kolmogorov-Smirnov, sin embargo funciona bien para muestras grandes)

# %%
# D'Agostino and Pearson test
from scipy.stats import kstest, norm, anderson, normaltest

# Test de normalidad
data = X_t0[numeric_var].copy()

normal_var = []
for var in numeric_var:
    statistic, p_value = normaltest(data[var])
    # print(f'Variable: {var}\n statistic: {statistic}    p_value: {p_value}\n')
    if p_value >= 0.05 : # No se rechaza la nula -> Los datos distribuyen normal
        normal_var.append(var)

normal_var
# Out:
# []

# %% [markdown]
# Para sorpresa nuestra, según los test realizados, ninguna de las variables numéricas distribuye normal.

# %%
from numpy import random

# plt.hist(X_t0['market_apo'], color='blue', label='market_apo');
plt.hist((X_t0['market_apo']-X_t0['market_apo'].mean())/X_t0['market_apo'].std(), color='blue', label='market_apo');
plt.hist(np.random.normal(0, 1, len(X_t0['market_cmo'])), alpha=0.5, color='red', label='normal');
plt.legend()

# %% [markdown]
# Observamos que estas variables tienen datos atípicos para una variable numérica

# %%
weird['binary']
# Out:
# ['market_ht_trendmode',
#  'unique_borrow_protocol_count',
#  'unique_lending_protocol_count']

# %%
from feature_engine.selection import SmartCorrelatedSelection

corr_var = SmartCorrelatedSelection(
    variables=None,
    method="pearson",
    threshold=0.9,
    missing_values="raise",
    selection_method="variance",
    estimator=None,
)

corr_var.fit_transform(X_t0)
# Set de variables correlacionadas
print(f'Variables correlacionas:\n {corr_var.correlated_feature_sets_}')

# Primera variable se retiene, se escoje la variable con mayor variabilidad del grupo.
print(f'Variables que retener:\n {corr_var.correlated_feature_dict_}')

# Variables por eliminar
print(f'Variables a eliminar:\n {corr_var.features_to_drop_}')

# Se puede definir un conjunto de variables que consideramos importantes de retener si o si e integrar esto a una pipeline
# Out:
# Variables correlacionas:
#  [{'risky_first_tx_timestamp', 'risky_last_tx_timestamp'}, {'first_tx_timestamp', 'wallet_age'}, {'borrow_block_number', 'last_tx_timestamp', 'borrow_timestamp'}, {'repay_count', 'risk_factor_above_threshold_daily_count', 'liquidation_amount_sum_eth', 'borrow_count', 'liquidation_count'}, {'incoming_tx_sum_eth', 'outgoing_tx_sum_eth'}, {'deposit_amount_sum_eth', 'withdraw_amount_sum_eth', 'borrow_amount_sum_eth'}, {'total_collateral_avg_eth', 'total_collateral_eth'}, {'outgoing_tx_count', 'deposit_count'}, {'incoming_tx_avg_eth', 'outgoing_tx_avg_eth'}, {'market_cmo', 'market_plus_di'}, {'market_ppo', 'market_apo', 'market_macd', 'market_macd_macdfix', 'market_macd_macdext'}, {'market_macdsignal_macdext', 'market_macdsignal_macdfix', 'market_macdsignal'}, {'market_linearreg_slope', 'market_rocr', 'market_rocp'}]
# Variables que retener:
#  {'risky_last_tx_timestamp': {'risky_first_tx_timestamp'}, 'first_tx_timestamp': {'wallet_age'}, 'last_tx_timestamp': {'borrow_block_number', 'borrow_timestamp'}, 'risk_factor_above_threshold_daily_count': {'repay_count', 'borrow_count', 'liquidation_count', 'liquidation_amount_sum_eth'}, 'incoming_tx_sum_eth': {'outgoing_tx_sum_eth'}, 'deposit_amount_sum_eth': {'withdraw_amount_sum_eth', 'borrow_amount_sum_eth'}, 'total_collateral_eth': {'total_collateral_avg_eth'}, 'outgoing_tx_count': {'deposit_count'}, 'incoming_tx_avg_eth': {'outgoing_tx_avg_eth'}, 'market_cmo': {'market_plus_di'}, 'market_apo': {'market_macd_macdfix', 'market_ppo', 'market_macd', 'market_macd_macdext'}, 'market_macdsignal_macdext': {'market_macdsignal_macdfix', 'market_macdsignal'}, 'market_linearreg_slope': {'market_rocr', 'market_rocp'}}
# Variables a eliminar:
#  ['risky_first_tx_timestamp', 'wallet_age', 'borrow_timestamp', 'borrow_block_number', 'liquidation_amount_sum_eth', 'borrow_count', 'repay_count', 'liquidation_count', 'outgoing_tx_sum_eth', 'withdraw_amount_sum_eth', 'borrow_amount_sum_eth', 'total_collateral_avg_eth', 'deposit_count', 'outgoing_tx_avg_eth', 'market_plus_di', 'market_macd_macdext', 'market_macd', 'market_macd_macdfix', 'market_ppo', 'market_macdsignal', 'market_macdsignal_macdfix', 'market_rocp', 'market_rocr']

# %%
pd.set_option("display.max_columns", maxcols)
# Histogramas para revisar el comportamiento de las variable
axes = X_t0[X_t0.drop(columns=weird['not']).columns].hist(figsize=(16,12), bins=15)
for ax in axes.flatten():
    ax.set_title(ax.get_title(), fontsize=10)
    ax.tick_params(axis='x', labelsize=6)
    ax.tick_params(axis='y', labelsize=6)

# %%
axes = X_t0[weird['not']].hist(figsize=(20,15), bins=15)
for ax in axes.flatten():
    ax.set_title(ax.get_title(), fontsize=10)
    ax.tick_params(axis='x', labelsize=6)
    ax.tick_params(axis='y', labelsize=6)

# %%
axes = X_t0[weird['not']].hist(figsize=(20,15), bins=15)
for ax in axes.flatten():
    ax.set_title(ax.get_title(), fontsize=10)
    ax.tick_params(axis='x', labelsize=6)
    ax.tick_params(axis='y', labelsize=6)

# %%
def plot_qqplot(df, columns, num_cols=7, dist='norm'):
    columns = columns if not isinstance(columns, str) else [columns]
    num_rows = int(len(columns)/num_cols)+min(1, len(columns)%num_cols)
    fig, axes = plt.subplots(num_rows, num_cols if num_rows != 1 else len(columns), sharex=True)
    axes = axes.reshape(-1) if isinstance(axes, type(np.array([]))) else [axes]
    box_dim = 2
    fig.set_figwidth(26 if num_rows > 1 else box_dim*len(columns))
    fig.set_figheight(num_rows*box_dim)

    for i, col in enumerate(columns):
        data, _ = stats.probplot(df[col], dist=dist, plot=axes[i])
        axes[i].set_title(col)
        if i!=0:
            axes[i].set_ylabel('')
        if isinstance(axes, type(np.array([]))) and i!=(len(axes)-1):
            axes[i].set_xlabel('')
    fig.set
    plt.show()

# %%
plot_qqplot(X_t0[numeric_var], cuasiconstant, num_cols=8)

# %%
X_corr = X_t0[numeric_var].corr()#.stack()
# X_corr = X_corr[X_corr.index.get_level_values(0) != X_corr.index.get_level_values(1)]
X_corr
# Out:
#                                        avg_gas_paid_per_tx_eth  \
# avg_gas_paid_per_tx_eth                               1.000000
# avg_risk_factor                                      -0.063659
# avg_weighted_risk_factor                              0.021849
# borrow_amount_avg_eth                                 0.053022
# borrow_amount_sum_eth                                 0.003014
# ...                                                        ...
# unique_borrow_protocol_count                          0.037969
# unique_lending_protocol_count                        -0.341478
# wallet_age                                           -0.067783
# withdraw_amount_sum_eth                               0.000450
# withdraw_deposit_diff_if_positive_eth                 0.000646
#
#                                        avg_risk_factor  \
# avg_gas_paid_per_tx_eth                      -0.063659
# avg_risk_factor                               1.000000
# avg_weighted_risk_factor                      0.211080
# borrow_amount_avg_eth                         0.026731
# borrow_amount_sum_eth                         0.324276
# ...                                                ...
# unique_borrow_protocol_count                  0.530372
# unique_lending_protocol_count                 0.154525
# wallet_age                                    0.124394
# withdraw_amount_sum_eth                       0.221071
# withdraw_deposit_diff_if_positive_eth         0.003673
#
#                                        avg_weighted_risk_factor  \
# avg_gas_paid_per_tx_eth                                0.021849
# avg_risk_factor                                        0.211080
# avg_weighted_risk_factor                               1.000000
# borrow_amount_avg_eth                                  0.566583
# borrow_amount_sum_eth                                  0.629033
# ...                                                         ...
# unique_borrow_protocol_count                           0.073727
# unique_lending_protocol_count                          0.021964
# wallet_age                                             0.101963
# withdraw_amount_sum_eth                                0.362635
# withdraw_deposit_diff_if_positive_eth                  0.032611
#
#                                        borrow_amount_avg_eth  \
# avg_gas_paid_per_tx_eth                             0.053022
# avg_risk_factor                                     0.026731
# avg_weighted_risk_factor                            0.566583
# borrow_amount_avg_eth                               1.000000
# borrow_amount_sum_eth                               0.352369
# ...                                                      ...
# unique_borrow_protocol_count                        0.059244
# unique_lending_protocol_count                       0.009957
# wallet_age                                          0.000388
# withdraw_amount_sum_eth                             0.254444
# withdraw_deposit_diff_if_positive_eth               0.030110
#
#                                        borrow_amount_sum_eth  \
# avg_gas_paid_per_tx_eth                             0.003014
# avg_risk_factor                                     0.324276
# avg_weighted_risk_factor                            0.629033
# borrow_amount_avg_eth                               0.352369
# borrow_amount_sum_eth                               1.000000
# ...                                                      ...
# unique_borrow_protocol_count                        0.112069
# unique_lending_protocol_count                       0.040761
# wallet_age                                          0.212303
# withdraw_amount_sum_eth                             0.842514
# withdraw_deposit_diff_if_positive_eth               0.263955
#
#                                        borrow_block_number  borrow_count  \
# avg_gas_paid_per_tx_eth                           0.151973     -0.029438
# avg_risk_factor                                  -0.081170      0.392183
# avg_weighted_risk_factor                          0.068809      0.274536
# borrow_amount_avg_eth                             0.094542     -0.011977
# borrow_amount_sum_eth                             0.108254      0.780827
# ...                                                    ...           ...
# unique_borrow_protocol_count                     -0.019662      0.120635
# unique_lending_protocol_count                     0.019701      0.045175
# wallet_age                                        0.148295      0.236384
# withdraw_amount_sum_eth                           0.111402      0.560643
# withdraw_deposit_diff_if_positive_eth             0.037054      0.023142
#
#                                        borrow_repay_diff_eth  \
# avg_gas_paid_per_tx_eth                             0.004180
# avg_risk_factor                                     0.330466
# avg_weighted_risk_factor                            0.692609
# borrow_amount_avg_eth                               0.348750
# borrow_amount_sum_eth                               0.916482
# ...                                                      ...
# unique_borrow_protocol_count                        0.101181
# unique_lending_protocol_count                       0.031593
# wallet_age                                          0.211766
# withdraw_amount_sum_eth                             0.653408
# withdraw_deposit_diff_if_positive_eth               0.138515
#
#                                        deposit_amount_sum_eth  deposit_count  \
# avg_gas_paid_per_tx_eth                              0.001867      -0.028217
# avg_risk_factor                                      0.275813       0.358954
# avg_weighted_risk_factor                             0.579506       0.244797
# borrow_amount_avg_eth                                0.371999      -0.010732
# borrow_amount_sum_eth                                0.918563       0.708301
# ...                                                       ...            ...
# unique_borrow_protocol_count                         0.107366       0.116993
# unique_lending_protocol_count                        0.045256       0.050380
# wallet_age                                           0.206878       0.229406
# withdraw_amount_sum_eth                              0.921489       0.524452
# withdraw_deposit_diff_if_positive_eth                0.176525       0.012242
#
#                                        ...  total_available_borrows_eth  \
# avg_gas_paid_per_tx_eth                ...                     0.051252
# avg_risk_factor                        ...                     0.007038
# avg_weighted_risk_factor               ...                     0.590850
# borrow_amount_avg_eth                  ...                     0.601050
# borrow_amount_sum_eth                  ...                     0.434160
# ...                                    ...                          ...
# unique_borrow_protocol_count           ...                     0.034039
# unique_lending_protocol_count          ...                     0.007497
# wallet_age                             ...                     0.066574
# withdraw_amount_sum_eth                ...                     0.475459
# withdraw_deposit_diff_if_positive_eth  ...                     0.141679
#
#                                        total_balance_eth  \
# avg_gas_paid_per_tx_eth                         0.006305
# avg_risk_factor                                -0.004290
# avg_weighted_risk_factor                        0.113979
# borrow_amount_avg_eth                           0.181835
# borrow_amount_sum_eth                           0.078853
# ...                                                  ...
# unique_borrow_protocol_count                    0.016407
# unique_lending_protocol_count                   0.015820
# wallet_age                                      0.046489
# withdraw_amount_sum_eth                         0.071456
# withdraw_deposit_diff_if_positive_eth           0.009230
#
#                                        total_collateral_avg_eth  \
# avg_gas_paid_per_tx_eth                                0.043421
# avg_risk_factor                                        0.132114
# avg_weighted_risk_factor                               0.926625
# borrow_amount_avg_eth                                  0.727843
# borrow_amount_sum_eth                                  0.598646
# ...                                                         ...
# unique_borrow_protocol_count                           0.066215
# unique_lending_protocol_count                          0.016097
# wallet_age                                             0.082635
# withdraw_amount_sum_eth                                0.425276
# withdraw_deposit_diff_if_positive_eth                  0.055031
#
#                                        total_collateral_eth  \
# avg_gas_paid_per_tx_eth                            0.045349
# avg_risk_factor                                    0.088108
# avg_weighted_risk_factor                           0.865775
# borrow_amount_avg_eth                              0.715542
# borrow_amount_sum_eth                              0.523706
# ...                                                     ...
# unique_borrow_protocol_count                       0.052093
# unique_lending_protocol_count                      0.010219
# wallet_age                                         0.055076
# withdraw_amount_sum_eth                            0.391980
# withdraw_deposit_diff_if_positive_eth              0.075298
#
#                                        total_gas_paid_eth  \
# avg_gas_paid_per_tx_eth                          0.037464
# avg_risk_factor                                  0.117742
# avg_weighted_risk_factor                         0.115519
# borrow_amount_avg_eth                            0.004512
# borrow_amount_sum_eth                            0.341976
# ...                                                   ...
# unique_borrow_protocol_count                     0.072417
# unique_lending_protocol_count                    0.013838
# wallet_age                                       0.140339
# withdraw_amount_sum_eth                          0.299858
# withdraw_deposit_diff_if_positive_eth            0.060147
#
#                                        unique_borrow_protocol_count  \
# avg_gas_paid_per_tx_eth                                    0.037969
# avg_risk_factor                                            0.530372
# avg_weighted_risk_factor                                   0.073727
# borrow_amount_avg_eth                                      0.059244
# borrow_amount_sum_eth                                      0.112069
# ...                                                             ...
# unique_borrow_protocol_count                               1.000000
# unique_lending_protocol_count                              0.117035
# wallet_age                                                 0.074858
# withdraw_amount_sum_eth                                    0.100920
# withdraw_deposit_diff_if_positive_eth                      0.020453
#
#                                        unique_lending_protocol_count  \
# avg_gas_paid_per_tx_eth                                    -0.341478
# avg_risk_factor                                             0.154525
# avg_weighted_risk_factor                                    0.021964
# borrow_amount_avg_eth                                       0.009957
# borrow_amount_sum_eth                                       0.040761
# ...                                                              ...
# unique_borrow_protocol_count                                0.117035
# unique_lending_protocol_count                               1.000000
# wallet_age                                                  0.108410
# withdraw_amount_sum_eth                                     0.042025
# withdraw_deposit_diff_if_positive_eth                       0.007695
#
#                                        wallet_age  withdraw_amount_sum_eth  \
# avg_gas_paid_per_tx_eth                 -0.067783                 0.000450
# avg_risk_factor                          0.124394                 0.221071
# avg_weighted_risk_factor                 0.101963                 0.362635
# borrow_amount_avg_eth                    0.000388                 0.254444
# borrow_amount_sum_eth                    0.212303                 0.842514
# ...                                           ...                      ...
# unique_borrow_protocol_count             0.074858                 0.100920
# unique_lending_protocol_count            0.108410                 0.042025
# wallet_age                               1.000000                 0.175796
# withdraw_amount_sum_eth                  0.175796                 1.000000
# withdraw_deposit_diff_if_positive_eth    0.014510                 0.431495
#
#                                        withdraw_deposit_diff_if_positive_eth
# avg_gas_paid_per_tx_eth                                             0.000646
# avg_risk_factor                                                     0.003673
# avg_weighted_risk_factor                                            0.032611
# borrow_amount_avg_eth                                               0.030110
# borrow_amount_sum_eth                                               0.263955
# ...                                                                      ...
# unique_borrow_protocol_count                                        0.020453
# unique_lending_protocol_count                                       0.007695
# wallet_age                                                          0.014510
# withdraw_amount_sum_eth                                             0.431495
# withdraw_deposit_diff_if_positive_eth                               1.000000
#
# [70 rows x 70 columns]

# %%
for i in range(len(X_corr)):
    for j in range(len(X_corr)):
        if i>j:
            X_corr.iloc[i,j] = pd.NA
            
heat = go.Heatmap(z=X_corr,
                  x=X_corr.columns,
                  y=X_corr.columns,
                  xgap=1, ygap=1,
                  colorbar_thickness=20,
                  colorbar_ticklen=3,
                  hoverinfo='text'
                  )

title = 'Matriz de Correlación'               
layout = go.Layout(title_text=title, title_x=0.5, 
                   width=1800, height=600,
                   xaxis_showgrid=False,
                   yaxis_showgrid=False,
                   yaxis_autorange='reversed')

fig=go.Figure(data=[heat], layout=layout)        
fig.show()

# %%
from sklearn.decomposition import PCA
client_map = {client:i for i, client in enumerate(sorted(X_t0['wallet_address'].unique()))}
X_t0['wallet_address_id'] = X_t0['wallet_address'].apply(lambda code: client_map[code])

# %%
pca_pipe = Pipeline([
    ('standard', StandardScaler()),
      ('pca', PCA(n_components=5))])
xpca = pca_pipe.fit_transform(X_t0[numeric_var])
plt.scatter(x=xpca[:,2], y=xpca[:,3], c = y_t0.to_numpy())

# %%
plt.scatter(x=xpca[:,2], y=xpca[:,3], c=X_t0['wallet_address_id'])

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# ##### **2.2 Preprocesamiento de Datos [0.25 puntos]**
#
# Esta sección se centra en la limpieza y preparación de los datos para garantizar que sean adecuados para el entrenamiento y evaluación de los modelos. Es fundamental ejecutar un **`train_test_split`** para dividir los datos en conjuntos de entrenamiento y validación, siguiendo la proporción establecida (por ejemplo, 70/30).
#
# Se espera la implementación de diversas técnicas de preprocesamiento, tales como:
# - **Uso de `ColumnTransformer`:** Permite aplicar transformaciones específicas a diferentes columnas de manera eficiente.
# - **Imputación de valores nulos:** Elija una estrategia adecuada (media, mediana, moda, etc.) para completar los datos faltantes.
# - **Discretización de variables:** Convierte variables numéricas continuas en categóricas, si resulta útil para el modelo.
# - **Estandarización o normalización:** Mejora el rendimiento de algunos algoritmos que son sensibles a la escala de los datos.
# - Otras transformaciones necesarias dependiendo de las características específicas del conjunto de datos.
#
# El proceso debe estar bien documentado y justificado en el informe, explicando las decisiones tomadas en función de los datos y los objetivos del proyecto.

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# Calcula el número de prestamos por wallet_address
class borrow_times(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.borrow_per_cli = None
        
    def fit(self, X, y=None):
        data = X.copy()
        object_var = data.select_dtypes(include='object').columns.to_list()
        vars = object_var + ['borrow_timestamp']

        self.borrow_per_cli = data[vars].groupby(*object_var).count()
        self.borrow_per_cli.rename(columns={'borrow_timestamp': 'borrow_times'}, inplace=True)
        self.borrow_per_cli.reset_index(inplace=True)
        return self
    
    def transform(self, X, y=None):
        data = X.copy()
        new_X = pd.merge(data, self.borrow_per_cli, on='wallet_address', how='left').fillna(0)
        new_X = new_X.sort_index(axis=1)
        return new_X

    def set_output(self,transform='default'):
        #No modificar este método
        return self

# Se calcula tiempo entre las_tx_timestamp y first_tx_timestamp = ts_diff_tx,
# Renombra 'risky_first_last_tx_timestamp_diff':'ts_diff_risky_tx'}
# Elimina las_tx_timestamp y first_tx_timestamp

class tx_diff(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.ts_diff_tx = None

    def fit(self, X, y=None):
        data = X.copy()
        self.data = data
        return self
    
    def transform(self, X, y=None):
        data = X.copy()
        data['ts_diff_tx'] = data['last_tx_timestamp'] - data['first_tx_timestamp']
        data.rename(columns={'risky_first_last_tx_timestamp_diff':'ts_diff_risky_tx'}, inplace=True)
        data.drop(columns=['last_tx_timestamp', 
                           'first_tx_timestamp',
                           'risky_last_tx_timestamp', 
                           'risky_first_tx_timestamp',
                           'borrow_timestamp'], inplace=True)
        
        new_data = data.sort_index(axis=1)
        return new_data

    def set_output(self,transform='default'):
        return self

class search_binary(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.binary_cols = []

    def fit(self, X, y=None):
        data = X.copy()
        for col in data.columns:
            diff_values = len(data[col].value_counts())
            is_binary = diff_values == 2
            if is_binary:
                self.binary_cols.append(col)
        return self
    
    def transform(self, X, y=None):
        data = X.copy()
        data[self.binary_cols] = data[self.binary_cols].astype('category')
        return data

    def set_output(self,transform='default'):
        return self

# %%
# timestamps = pd.Index([col for col in X_t0.columns if "timestamp" in col])
# to_datetime_func = FunctionTransformer(lambda df: df.map(lambda ms: datetime.datetime.fromtimestamp(ms)))

# %%
# timestamps = [col for col in X_t0.columns if "timestamp" in col]
# timestamps

# %%
class time_tranf(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.time_cols = []

    def fit(self, X, y=None):
        data = X.copy()
        tcols = [col for col in data.columns if "timestamp" in col]
        self.time_cols = tcols
        return self
    
    def transform(self, X, y=None):
        data = X.copy()
        for col in self.time_cols:
            data[col] = data[col].apply(lambda x: datetime.datetime.fromtimestamp(x))
        return data

    def set_output(self,transform='default'):
        return self

# %%
# time_cols().fit_transform(X_t0)

# %%
from sklearn.compose import make_column_selector

first_transformer = ColumnTransformer([
                            # ('drop_times', 'drop', make_column_selector(dtype_include=datetime)),
                            ('scale_data', MinMaxScaler(), make_column_selector(dtype_include=np.number) ),
                            ('object', 'drop', make_column_selector(dtype_include=object) ),
                            ('categorical', 'passthrough', make_column_selector(dtype_include='category'))
                            ], 
                            remainder='passthrough', 
                            verbose_feature_names_out=False)
first_transformer.set_output(transform='pandas')
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('scale_data', MinMaxScaler(),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000002D5B8CB3D90>),
#                                 ('object', 'drop',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000002D5D74361D0>),
#                                 ('categorical', 'passthrough',
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000002D5D74349D0>)],
#                   verbose_feature_names_out=False)

# %%
transf_pipe = Pipeline([
                ('add_borrow', borrow_times()),
                ('diff_tranf', tx_diff()),
                ('binary_cols', search_binary()),
                ('time_cols', time_tranf()),
                ('cols_transf', first_transformer),
                ])

# %%
# transf_pipe.fit_transform(X_t0).info()

# %%
# plot_qqplot(optimus, weird['binary'])

# %% [markdown]
# qqplot esperado para varible binaria

# %%
# plot_qqplot(optimus, weird['max_prop'])

# %% [markdown]
# Este campo se asumirá como variable binaria

# %%
# print(", ".join(weird['min_prop']))
# plot_qqplot(optimus, weird['min_prop'])

# %% [markdown]
# Podemos observar en las primeras 5 variables un comportamiento parecido a una variable binaria. Para facilitar la predicción al modelo, podemos definir para ellas 3 o 4 bins, donde los bins 2 y 3 serían valores de transición desde los menores a los mayores valores encontrados.

# %% [markdown]
# Para las demás variables, vemos comportamientos interesantes. Por ejemplo para `max_market_drawdown_365d` se observan valores escalonados, lo que también podría permitirnos simplificar estos valores en bins. A su vez, vemos que varias se comportan de manera normal.

# %%
# X_corr = X_t0[weird['not']].corr()

# fig = go.Figure()
# fig.add_trace(
#     go.Heatmap(
#         x = X_corr.columns,
#         y = X_corr.index,
#         z = np.array(X_corr),
#         text=X_corr.values,
#         texttemplate='%{text:.2f}'
#     )
# )
# fig.update_layout(title_text='Correlación entre las variables numéricas',
#                     height=800, width=1400)
# fig.show()

# %% [markdown]
# # División cjto de datos

# %% [markdown]
# Dado que las clases están en proporciones relativamente similares, no consideramos necesario

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_t0, y_t0.values, 
                                                    test_size=0.0001, random_state=29, shuffle=True,)

# %% [markdown]
# # Baseline

# %% [markdown]
# ##### **2.3 Baseline [0.25 puntos]**
#
# En esta sección se debe construir el modelo más sencillo posible que pueda resolver el problema planteado, conocido como **modelo baseline**. Su propósito es servir como referencia para comparar el rendimiento de los modelos más avanzados desarrollados en etapas posteriores.
#
# Pasos requeridos:
# - Implemente, entrene y evalúe un modelo básico utilizando un pipeline.
# - Asegúrese de incluir en el pipeline las transformaciones del preprocesamiento realizadas previamente junto con un clasificador básico.
# - Evalúe el modelo y presente el informe de métricas utilizando **`classification_report`**.
#
# Documente claramente cómo se creó el modelo, las decisiones tomadas y los resultados obtenidos. Este modelo será la base comparativa en las secciones posteriores.
#
# ---

# %%
from sklearn.dummy import DummyClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import roc_curve, roc_auc_score, auc
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# %%
dummy_pipe = Pipeline([
                    ('preprocess', transf_pipe),
                    ('dummy_clf', DummyClassifier(strategy='most_frequent'))
                    ])

# %%
# dummy_pipe.fit(X_train, y_train)
# y_dummy = dummy_pipe.predict(X_test)
# dummy_pipe.score(X_test, y_test)

# %%
# dummy_clf = DummyClassifier(strategy='most_frequent')
# dummy_clf.fit(X_train, y_train)
# y_dummy = dummy_clf.predict(X_test)

# # dummy.score:Return the mean accuracy on the given test data and labels.
# dummy_clf.score(X_test, y_test)

# %%
# lsvc_pipe = Pipeline([
#                     ('preprocess', transf_pipe),
#                     ('lsvc_clf', LinearSVC(random_state=29))
#                     ])
# # lsvc_clf = LinearSVC(random_state=29)
# lsvc_pipe.fit(X_train, y_train)
# y_lsvc = lsvc_pipe.predict(X_test)
# lsvc_pipe.score(X_test, y_test)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_pipe = Pipeline([
                ('preprocess', transf_pipe),
                ('randomForest', RandomForestClassifier(criterion='entropy', random_state=29))
                ])
rf_pipe.fit(X_t0, y_t0)
y_rf = rf_pipe.predict_proba(X_test)
# rf_pipe.score(X_test, y_test)
y_rf
# Out:
# d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\base.py:1473: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[204], line 7
#       1 from sklearn.ensemble import RandomForestClassifier
#       3 rf_pipe = Pipeline([
#       4                 ('preprocess', transf_pipe),
#       5                 ('randomForest', RandomForestClassifier(criterion='entropy', random_state=29))
#       6                 ])
# ----> 7 rf_pipe.fit(X_t0, y_t0)
#       8 y_rf = rf_pipe.predict_proba(X_test)
#       9 # rf_pipe.score(X_test, y_test)
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\pipeline.py:473, in Pipeline.fit(self, X, y, **params)
#     471     if self._final_estimator != "passthrough":
#     472         last_step_params = routed_params[self.steps[-1][0]]
# --> 473         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     475 return self
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\ensemble\_forest.py:489, in BaseForest.fit(self, X, y, sample_weight)
#     478 trees = [
#     479     self._make_estimator(append=False, random_state=random_state)
#     480     for i in range(n_more_estimators)
#     481 ]
#     483 # Parallel loop: we prefer the threading backend as the Cython code
#     484 # for fitting the trees is internally releasing the Python GIL
#     485 # making threading more efficient than multiprocessing in
#     486 # that case. However, for joblib 0.12+ we respect any
#     487 # parallel_backend contexts set at a higher level,
#     488 # since correctness does not rely on using threads.
# --> 489 trees = Parallel(
#     490     n_jobs=self.n_jobs,
#     491     verbose=self.verbose,
#     492     prefer="threads",
#     493 )(
#     494     delayed(_parallel_build_trees)(
#     495         t,
#     496         self.bootstrap,
#     497         X,
#     498         y,
#     499         sample_weight,
#     500         i,
#     501         len(trees),
#     502         verbose=self.verbose,
#     503         class_weight=self.class_weight,
#     504         n_samples_bootstrap=n_samples_bootstrap,
#     505         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     506     )
#     507     for i, t in enumerate(trees)
#     508 )
#     510 # Collect newly grown trees
#     511 self.estimators_.extend(trees)
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\utils\parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\joblib\parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\joblib\parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\utils\parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\ensemble\_forest.py:192, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     189     elif class_weight == "balanced_subsample":
#     190         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 192     tree._fit(
#     193         X,
#     194         y,
#     195         sample_weight=curr_sample_weight,
#     196         check_input=False,
#     197         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     198     )
#     199 else:
#     200     tree._fit(
#     201         X,
#     202         y,
#    (...)
#     205         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     206     )
#
# File d:\FCFM\Primavera2024\Lab\Labs_MDS\.venv\lib\site-packages\sklearn\tree\_classes.py:472, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     461 else:
#     462     builder = BestFirstTreeBuilder(
#     463         splitter,
#     464         min_samples_split,
#    (...)
#     469         self.min_impurity_decrease,
#     470     )
# --> 472 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     474 if self.n_outputs_ == 1 and is_classifier(self):
#     475     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
rf_pipe.score(X_test, y_test)
# Out:
# 1.0

# %%
X_t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44296 entries, 44296 to 88591
# Data columns (total 77 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   avg_gas_paid_per_tx_eth                  44296 non-null  float64
#  1   avg_risk_factor                          44296 non-null  float64
#  2   avg_weighted_risk_factor                 44296 non-null  float64
#  3   borrow_amount_avg_eth                    44296 non-null  float64
#  4   borrow_amount_sum_eth                    44296 non-null  float64
#  5   borrow_block_number                      44296 non-null  int64
#  6   borrow_count                             44296 non-null  int64
#  7   borrow_repay_diff_eth                    44296 non-null  float64
#  8   borrow_timestamp                         44296 non-null  float64
#  9   deposit_amount_sum_eth                   44296 non-null  float64
#  10  deposit_count                            44296 non-null  int64
#  11  first_tx_timestamp                       44296 non-null  float64
#  12  incoming_tx_avg_eth                      44296 non-null  float64
#  13  incoming_tx_count                        44296 non-null  int64
#  14  incoming_tx_sum_eth                      44296 non-null  float64
#  15  last_tx_timestamp                        44296 non-null  float64
#  16  liquidation_amount_sum_eth               44296 non-null  float64
#  17  liquidation_count                        44296 non-null  int64
#  18  market_adx                               44296 non-null  float64
#  19  market_adxr                              44296 non-null  float64
#  20  market_apo                               44296 non-null  float64
#  21  market_aroonosc                          44296 non-null  float64
#  22  market_aroonup                           44296 non-null  float64
#  23  market_atr                               44296 non-null  float64
#  24  market_cci                               44296 non-null  float64
#  25  market_cmo                               44296 non-null  float64
#  26  market_correl                            44296 non-null  float64
#  27  market_dx                                44296 non-null  float64
#  28  market_fastd                             44296 non-null  float64
#  29  market_fastk                             44296 non-null  float64
#  30  market_ht_trendmode                      44296 non-null  int64
#  31  market_linearreg_slope                   44296 non-null  float64
#  32  market_macd                              44296 non-null  float64
#  33  market_macd_macdext                      44296 non-null  float64
#  34  market_macd_macdfix                      44296 non-null  float64
#  35  market_macdsignal                        44296 non-null  float64
#  36  market_macdsignal_macdext                44296 non-null  float64
#  37  market_macdsignal_macdfix                44296 non-null  float64
#  38  market_max_drawdown_365d                 44296 non-null  float64
#  39  market_natr                              44296 non-null  float64
#  40  market_plus_di                           44296 non-null  float64
#  41  market_plus_dm                           44296 non-null  float64
#  42  market_ppo                               44296 non-null  float64
#  43  market_rocp                              44296 non-null  float64
#  44  market_rocr                              44296 non-null  float64
#  45  max_eth_ever                             44296 non-null  float64
#  46  max_risk_factor                          44296 non-null  float64
#  47  min_eth_ever                             44296 non-null  float64
#  48  net_incoming_tx_count                    44296 non-null  int64
#  49  outgoing_tx_avg_eth                      44296 non-null  float64
#  50  outgoing_tx_count                        44296 non-null  int64
#  51  outgoing_tx_sum_eth                      44296 non-null  float64
#  52  repay_amount_avg_eth                     44296 non-null  float64
#  53  repay_amount_sum_eth                     44296 non-null  float64
#  54  repay_count                              44296 non-null  int64
#  55  risk_factor                              44296 non-null  float64
#  56  risk_factor_above_threshold_daily_count  44296 non-null  float64
#  57  risky_first_last_tx_timestamp_diff       44296 non-null  int64
#  58  risky_first_tx_timestamp                 44296 non-null  int64
#  59  risky_last_tx_timestamp                  44296 non-null  int64
#  60  risky_sum_outgoing_amount_eth            44296 non-null  float64
#  61  risky_tx_count                           44296 non-null  int64
#  62  risky_unique_contract_count              44296 non-null  int64
#  63  time_since_first_deposit                 44296 non-null  float64
#  64  time_since_last_liquidated               44296 non-null  float64
#  65  total_available_borrows_avg_eth          44296 non-null  float64
#  66  total_available_borrows_eth              44296 non-null  float64
#  67  total_balance_eth                        44296 non-null  float64
#  68  total_collateral_avg_eth                 44296 non-null  float64
#  69  total_collateral_eth                     44296 non-null  float64
#  70  total_gas_paid_eth                       44296 non-null  float64
#  71  unique_borrow_protocol_count             44296 non-null  int64
#  72  unique_lending_protocol_count            44296 non-null  int64
#  73  wallet_address                           44296 non-null  object
#  74  wallet_age                               44296 non-null  float64
#  75  withdraw_amount_sum_eth                  44296 non-null  float64
#  76  withdraw_deposit_diff_if_positive_eth    44296 non-null  float64
# dtypes: float64(60), int64(16), object(1)
# memory usage: 26.0+ MB

# %%
from zipfile import ZipFile
import os
def generateFiles(predict_data, clf_pipe):
    """Genera los archivos a subir en CodaLab

    Input
    ---------------
    predict_data: Dataframe con los datos de entrada a predecir
    clf_pipe: pipeline del clf

    Ouput
    ---------------
    archivo de txt
    """
    y_pred_clf = clf_pipe.predict_proba(predict_data)[:, 1]
    with open('./predictions.txt', 'w') as f:
        for item in y_pred_clf:
            f.write("%s\n" % item)
    
    with ZipFile('predictions.zip', 'w') as zipObj:
        zipObj.write('predictions.txt')
    os.remove('predictions.txt')

generateFiles(X_t1, rf_pipe)

# %%
print(classification_report(y_test, y_dummy))
print(classification_report(y_test, y_lsvc))
print(classification_report(y_test, y_rf))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 print(classification_report(y_test, y_dummy))
#       2 print(classification_report(y_test, y_lsvc))
#       3 print(classification_report(y_test, y_rf))
#
# NameError: name 'y_dummy' is not defined

# %% [markdown]
# The precision-recall curve shows the tradeoff between precision and recall for different thresholds. A high area under the curve represents both high recall and high precision. High precision is achieved by having few false positives in the returned results, and high recall is achieved by having few false negatives in the relevant results. High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all relevant results (high recall).

# %%
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay

y_lsvc = lsvc_clf.predict(X_test.drop(columns=[*timestamps, *object_var]))
precision, recall, _ = precision_recall_curve(y_test, y_lsvc)
disp = PrecisionRecallDisplay(precision=precision, recall=recall, estimator_name="LinearSVC")
disp.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[217], line 3
#       1 from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay
# ----> 3 y_lsvc = lsvc_clf.predict(X_test.drop(columns=[*timestamps, *object_var]))
#       4 precision, recall, _ = precision_recall_curve(y_test, y_lsvc)
#       5 disp = PrecisionRecallDisplay(precision=precision, recall=recall, estimator_name="LinearSVC")
#
# NameError: name 'lsvc_clf' is not defined

# %% [markdown]
# # 3 modelos de ML (nuevos)

# %% [markdown]
# ---
#
# ##### **2.4 Modelos de Machine Learning [0.5 puntos]**
#
# Esta sección debe detallar la creación de tres modelos más avanzados. Cada modelo debe incluirse en un pipeline que combine el preprocesamiento de datos y un clasificador. A continuación, describa:
# - **Estructura y diferencias entre los modelos:** Explique los clasificadores seleccionados, sus hiperparámetros iniciales y el enfoque utilizado para cada uno.
# - **Resultados:** Evalúe cada modelo utilizando **`classification_report`**, destacando métricas clave como precisión, recall y F1-score.
# - **Clasificadores sugeridos:** Puede seleccionar entre los siguientes:
#   - `LogisticRegression`
#   - `KNeighborsClassifier`
#   - `DecisionTreeClassifier`
#   - `SVC`
#   - `RandomForestClassifier`
#   - `LightGBMClassifier` (del paquete `lightgbm`)
#   - `XGBClassifier` (del paquete `xgboost`)
#   - Otro
#
# Además, responda las siguientes preguntas para evaluar el rendimiento de los modelos:
# 1. ¿Hay algún clasificador que supere al modelo baseline?
# 2. ¿Cuál es el mejor clasificador entrenado y por qué?
# 3. ¿Qué factores hacen que el mejor clasificador sea superior a los otros?
# 4. En términos de tiempo de entrenamiento, ¿qué modelo considera más adecuado para experimentar con grillas de optimización?
#
# Finalmente, seleccione **uno de los tres modelos** desarrollados para continuar con las siguientes secciones. Justifique su elección basándose en criterios metodológicos y de rendimiento, explicando por qué este modelo es el más adecuado para abordar el problema planteado.
#
# Además, se recomienda realizar un análisis preliminar de interpretabilidad sobre su modelo baseline utilizando herramientas básicas. Esto le permitirá comprender de manera general cómo el modelo está tomando decisiones y podría ser de gran utilidad más adelante, cuando trabaje con su modelo final, para comparar y validar los resultados obtenidos.
#
# ---

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf = DecisionTreeClassifier(random_state=29)
tree_clf = tree_clf.fit(X_train, y_train)
y_tree = tree_clf.predict(X_test)

# %%
# print(classification_report(y_test, y_tree, zero_division=0))

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

logistic_clf = LogisticRegression(random_state=29, solver='liblinear')
logistic_clf.fit(X_train, y_train[:,0])
y_log = logistic_clf.predict(X_test)

# %%
y_log = logistic_clf.predict(X_test)
print(classification_report(y_test, y_log, zero_division=0))

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC

svc_clf = SVC(random_state=29)
svc_clf.fit(X_train, y_train)

# %%
y_svc = svc_clf.predict(X_test)
print(classification_report(y_test, y_svc))

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

random_clf = RandomForestClassifier(criterion='entropy', random_state=29)
random_clf.fit(X_train, y_train)

# %%
y_random = random_clf.predict(X_test)
print(classification_report(y_test, y_random, zero_division=0))

# %% [markdown]
# ## AUC PR
# Plot de Precision-Recall AUC

# %%
from sklearn.metrics import precision_recall_curve, auc

# y_true: valores reales
# y_scores: probabilidades predichas por el modelo
models =  [dummy_clf, tree_clf, random_clf, svc_clf]
models_names = ['DummyClassifier', 'DecisionTreeClassifier', 'RandomForest', 'SVC']

for i, model in enumerate(models):
    print(models_names[i])
    precision, recall, thresholds = precision_recall_curve(y_test, model.predict(X_test))
    auc_pr = auc(recall, precision)
    
    print("AUC-PR:", auc_pr)

# %%
# AUC curve
models =  [dummy_clf, tree_clf, random_clf, svc_clf] 
models_names = ['DummyClassifier', 'DecisionTreeClassifier', 'RandomForest', 'SVC']


for i, model in enumerate(models):
    y_predicted = model.predict(X_test)

    fpr, tpr, thresholds = roc_curve(y_test.ravel(), y_predicted, pos_label=1)
    auc(fpr, tpr)
    fpr, tpr, _ = roc_curve(y_test.ravel(), y_predicted, pos_label=1)
    roc_auc = roc_auc_score(y_test.ravel(), y_predicted)

    plt.plot(fpr, tpr, lw=2, label=f'{models_names[i]}(area = %0.2f)' % roc_auc)

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', alpha=0.3)
plt.legend(title='ROC Curves')

plt.title('AUC Curves')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')

# %%
print(classification_report(y_test, y_tree ))

# %%
print(classification_report(y_test, y_random))
